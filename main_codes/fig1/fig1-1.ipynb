# %%
import scanpy as sc
import rapids_singlecell as rsc
import matplotlib.pyplot as plt
import numpy as np
import os
import numba
import pandas as pd
from scipy.sparse import csr_matrix
from scipy.sparse import issparse
import anndata as ad

# %%
##gse242299
##gsm7757833_T2_1 lack values,aborted；GSM7757855_N3_1 has empty file,aborted
p2_t22 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757834_T2_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t31 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757835_T3_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t32 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757836_T3_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t42 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757837_T4_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t51 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757838_T5_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t52 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757839_T5_2",
                         var_names='gene_symbols',cache=True)######no treatment
p2_t61 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757840_T6_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t62 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757841_T6_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t63 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757842_T6_3",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t71 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757843_T7_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t72 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757844_T7_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t73 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757845_T7_3",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t81 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757846_T8_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t82 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757847_T8_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t83 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757848_T8_3",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t91 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757849_T9_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t92 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757850_T9_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_t93 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757851_T9_3",
                         var_names='gene_symbols',cache=True)###no treatment


##normal tissue
p2_n11 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757852_N1_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n21 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757853_N2_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n22 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757854_N2_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n32 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757856_N3_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n41 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757857_N4_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n42 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757858_N4_2",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n51 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757859_N5_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n61 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757860_N6_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n71 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757861_N7_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n81 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757862_N8_1",
                         var_names='gene_symbols',cache=True)###no treatment
p2_n91 = sc.read_10x_mtx(path="./datasets/2/gse242299/GSE242299_RAW/GSM7757863_N9_1",
                         var_names='gene_symbols',cache=True)###no treatment

# %%
##pr1's cancer and Normal adjencent tissue were aborted，because it was pRCC
###（chemotherapy for collicular lymphoma）p3_pr9pt =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392403_RCC-PR9-PTumor.count.csv.gz")
p3_pr6pt = sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392399_pr6pt/outs/filtered_feature_bc_matrix/")###no treatment
p3_pr7pt = sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392401_pr7pt/outs/filtered_feature_bc_matrix/")###no treatment
#p3_pr9pt2 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392404_pr9pt2/outs/filtered_feature_bc_matrix/")####ccRCC thrombus
p3_pr5pt1 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392406_pr5pt1/outs/filtered_feature_bc_matrix/")###no treatment
p3_pr5pt2 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392407_pr5pt2/outs/filtered_feature_bc_matrix/")####no treatment
p3_pr5pt3 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392408_pr5pt3/outs/filtered_feature_bc_matrix/")####no treatment
#p3_bm1pt  =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392409_bm1pt/outs/filtered_feature_bc_matrix/")
#p3_bm2pt1 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392411_bm2pt1/outs/filtered_feature_bc_matrix/")
#p3_bm2pt2 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392412_bm2pt2/outs/filtered_feature_bc_matrix/")
p3_pr2pt =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392417_pr2pt/outs/filtered_feature_bc_matrix/")###no treatment
p3_pr4pt =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392419_pr4pt/outs/filtered_feature_bc_matrix/")###no treatment
p3_pr3pt1 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392421_pr3pt1/outs/filtered_feature_bc_matrix/")####no treatment
p3_pr3pt2 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392422_pr3pt2/outs/filtered_feature_bc_matrix/")####no treatment
p3_pr3pt3 =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392423_pr3pt3/outs/filtered_feature_bc_matrix/")####no treatment

p3_pr6n = sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392398_pr6n/outs/filtered_feature_bc_matrix/")###no treatment
p3_pr8n = sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392400_pr8n/outs/filtered_feature_bc_matrix/")###no treatment 
#p3_pr9n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392402_pr9n/outs/filtered_feature_bc_matrix/")
p3_pr5n   =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392405_pr5n/outs/filtered_feature_bc_matrix/")####no treatment
#p3_bm1n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392410_bm1n/outs/filtered_feature_bc_matrix/")
#p3_bm2n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392413_bm2n/outs/filtered_feature_bc_matrix/")

p3_pr2n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392416_pr2n/outs/filtered_feature_bc_matrix/")####no treatment
p3_pr4n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392418_pr4n/outs/filtered_feature_bc_matrix/")####no treatment
p3_pr3n =  sc.read_10x_mtx("./datasets/3/GSE178481_RAW/result/GSM5392420_pr3n/outs/filtered_feature_bc_matrix/")####no treatment

# %%
##read paper11
p11_1 = sc.read_10x_mtx(path="./datasets/11/GSM4630028_ccRCC1",###no treatment
                         var_names='gene_symbols',cache=True)
p11_2 = sc.read_10x_mtx(path="./datasets/11/GSM4630029_ccRCC2",###no treatment
                         var_names='gene_symbols',cache=True)
#p11_3  = sc.read_10x_mtx(path="./datasets/11/GSM4630031_Normal_kidney/",###no treatment###chRCC para-tumor
#                        var_names='gene_symbols',cache=True)

# %%
##paper12
##gse111360 is all expressing cd45+
p12_1 = sc.read_10x_mtx(path="./datasets/12/GSE171306/GSM5222644_ccRCC1",
                         var_names='gene_symbols',cache=True)####no treatment
p12_2 = sc.read_10x_mtx(path="./datasets/12/GSE171306/GSM5222645_ccRCC2",
                         var_names='gene_symbols',cache=True)####no treatment

# %%
###paper14
#gse131685 is all normal tissue
#p14_k1 = sc.read_10x_mtx(path="./datasets/14/GSE131685/GSM4145204_kidney1",Not ccRCC,Papillary urothelial carcinoma of the renal pelvis
                         #var_names='gene_symbols',cache=True)
p14_k2 = sc.read_10x_mtx(path="./datasets/14/GSE131685/GSM4145205_kidney2",###
                         var_names='gene_symbols',cache=True)
p14_k3 = sc.read_10x_mtx(path="./datasets/14/GSE131685/GSM4145206_kidney3",###
                         var_names='gene_symbols',cache=True)

# %%
#paper14
##gse156632
#p14_1t  = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735364_1t/outs/filtered_feature_bc_matrix/")###metastasis
#p14_1n = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735365_1n/outs/filtered_feature_bc_matrix/")
p14_2t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735366_2t/outs/filtered_feature_bc_matrix/")
p14_2n = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735367_2n/outs/filtered_feature_bc_matrix/")
p14_3t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735368_3t/outs/filtered_feature_bc_matrix/")
p14_3n = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735369_3n/outs/filtered_feature_bc_matrix/")
#p14_4t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735370_4t/outs/filtered_feature_bc_matrix/")##ccRCC+pRCC
#p14_4n = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735371_4n/outs/filtered_feature_bc_matrix/")
p14_5t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735372_5t/outs/filtered_feature_bc_matrix/")
p14_5n = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735373_5n/outs/filtered_feature_bc_matrix/")
p14_6t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735374_6t/outs/filtered_feature_bc_matrix/")
p14_7t = sc.read_10x_mtx("./datasets/14/GSE156632/results/GSM4735375_7t/outs/filtered_feature_bc_matrix/")###

# %%
###paper24
##GSE210038
#p24_t1 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415686_t1/outs/filtered_feature_bc_matrix/")##Nivolumab+Ipilimumab
p24_t2 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415687_t2/outs/filtered_feature_bc_matrix/")
#p24_t3 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415688_t3/outs/filtered_feature_bc_matrix/")###Sunitinib
p24_t4 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415689_t4/outs/filtered_feature_bc_matrix/")
p24_t5 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415690_t5/outs/filtered_feature_bc_matrix/")
p24_t6 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415691_t6/outs/filtered_feature_bc_matrix/")
p24_t7 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415692_t7/outs/filtered_feature_bc_matrix/")
###p24_n1 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415693_n1/outs/filtered_feature_bc_matrix/")###mixed samples excluded
p24_n2 = sc.read_10x_mtx("./datasets/24/GSE210038_RAW/results/GSM6415694_n2/outs/filtered_feature_bc_matrix/")

# %%
p31_rcc81 = sc.read_10x_mtx("./datasets/31/RCC81/")####no treatment
p31_rcc84 = sc.read_10x_mtx("./datasets/31/RCC84/")####no treatment
p31_rcc86 = sc.read_10x_mtx("./datasets/31/RCC86/")####no treatment
p31_rcc87 = sc.read_10x_mtx("./datasets/31/RCC87/")####no treatment
p31_rcc94 = sc.read_10x_mtx("./datasets/31/RCC94/")####no treatment
p31_rcc96 = sc.read_10x_mtx("./datasets/31/RCC96/")####no treatment
p31_rcc99 = sc.read_10x_mtx("./datasets/31/RCC99/")####no treatment
p31_rcc100 = sc.read_10x_mtx("./datasets/31/RCC100/")####no treatment
p31_rcc101 = sc.read_10x_mtx("./datasets/31/RCC101/")####no treatment
p31_rcc103 = sc.read_10x_mtx("./datasets/31/RCC103/")####no treatment
p31_rcc104 = sc.read_10x_mtx("./datasets/31/RCC104/")####no treatment
p31_rcc106 = sc.read_10x_mtx("./datasets/31/RCC106/")####no treatment
p31_rcc112 = sc.read_10x_mtx("./datasets/31/RCC112/")####no treatment
p31_rcc113 = sc.read_10x_mtx("./datasets/31/RCC113/")####no treatment
p31_rcc114 = sc.read_10x_mtx("./datasets/31/RCC114/")####no treatment
p31_rcc115 = sc.read_10x_mtx("./datasets/31/RCC115/")####no treatment
p31_rcc116 = sc.read_10x_mtx("./datasets/31/RCC116/")####no treatment
p31_rcc119 = sc.read_10x_mtx("./datasets/31/RCC119/")####no treatment
p31_rcc120 = sc.read_10x_mtx("./datasets/31/RCC120/")####no treatment

# %%
######status
tumor_samples = [
    p2_t22, p2_t31, p2_t32, p2_t42, p2_t51, p2_t52, p2_t61, p2_t62, p2_t63, p2_t71, p2_t72, p2_t73, p2_t81, p2_t82, p2_t83, p2_t91, p2_t92, p2_t93,
    p3_pr6pt, p3_pr7pt, p3_pr5pt1, p3_pr5pt2, p3_pr5pt3,p3_pr2pt, p3_pr4pt, p3_pr3pt1, p3_pr3pt2, p3_pr3pt3,##updated
    p11_1,p11_2,
    p12_1,p12_2,
    p14_2t, p14_3t, p14_5t, p14_6t, p14_7t,
    p24_t2, p24_t4, p24_t5, p24_t6, p24_t7,
    p31_rcc81, p31_rcc84, p31_rcc86, p31_rcc87, p31_rcc94,
    p31_rcc96, p31_rcc99, p31_rcc100, p31_rcc101, p31_rcc103,
    p31_rcc104, p31_rcc106, p31_rcc112, p31_rcc113, p31_rcc114,
    p31_rcc115, p31_rcc116, p31_rcc119, p31_rcc120
]
normal_samples = [
    p2_n11, p2_n21, p2_n22, p2_n32, p2_n41,p2_n42, p2_n51, p2_n61, p2_n71, p2_n81, p2_n91,
    p3_pr6n, p3_pr8n, p3_pr5n, p3_pr2n, p3_pr4n, p3_pr3n,
    p14_k2,p14_k3,
    p14_2n, p14_3n, p14_5n,
    p24_n2
    
]
for adata in tumor_samples:
    adata.obs['status'] = 'tumor'

for adata in normal_samples:
    adata.obs['status'] = 'normal-like'

# %%
#####################

sample_p22 = [
    p2_t22, p2_t31, p2_t32, p2_t42, p2_t51, p2_t52, 
    p2_t61, p2_t62, p2_t63, p2_t71, p2_t72, p2_t73, 
    p2_t81, p2_t82, p2_t83, p2_t91, p2_t92, p2_t93,
    p2_n11, p2_n21, p2_n22, p2_n32, p2_n41, p2_n42, 
    p2_n51, p2_n61, p2_n71, p2_n81, p2_n91
]


key_p22_varnames = [
    "p2_t22", "p2_t31", "p2_t32", "p2_t42", "p2_t51", "p2_t52", 
    "p2_t61", "p2_t62", "p2_t63", "p2_t71", "p2_t72", "p2_t73", 
    "p2_t81", "p2_t82", "p2_t83", "p2_t91", "p2_t92", "p2_t93",
    "p2_n11", "p2_n21", "p2_n22", "p2_n32", "p2_n41", "p2_n42", 
    "p2_n51", "p2_n61", "p2_n71", "p2_n81", "p2_n91"
]


p22_all = sc.concat(sample_p22, keys=key_p22_varnames, label="sample")
##################
sample_p3 = [
    p3_pr6pt, p3_pr7pt, p3_pr5pt1, p3_pr5pt2, p3_pr5pt3,
    p3_pr2pt, p3_pr4pt, p3_pr3pt1, p3_pr3pt2, p3_pr3pt3,
    p3_pr6n, p3_pr8n, p3_pr5n, p3_pr2n, p3_pr4n, p3_pr3n
]


key_p3_varnames = [
    "p3_pr6pt", "p3_pr7pt", "p3_pr5pt1", "p3_pr5pt2", "p3_pr5pt3",
    "p3_pr2pt", "p3_pr4pt", "p3_pr3pt1", "p3_pr3pt2", "p3_pr3pt3",
    "p3_pr6n", "p3_pr8n", "p3_pr5n", "p3_pr2n", "p3_pr4n", "p3_pr3n"
]


p3_all = sc.concat(sample_p3, keys=key_p3_varnames, label="sample")


######################
sample_p11 = [p11_1,p11_2
]
key_p11 = [
    "p11_1",
    "p11_2"
]
p11_all = sc.concat(sample_p11, keys=key_p11, label="sample")
#####################

sample_p12=[p12_1,p12_2]
key_p12 = [
    "p12_1", 
    "p12_2"
]
p12_all = sc.concat(sample_p12, keys=key_p12, label="sample")
###############
sample_p141 = [
    p14_k2, p14_k3,
]
key_p141 = [
    "p14_k2", "p14_k3",
]
p141_all = sc.concat(sample_p141,keys=key_p141,label="sample")
########################
sample_p142 = [
    p14_2t, p14_3t, p14_5t, p14_6t, p14_7t,
    p14_2n, p14_3n, p14_5n
]
key_p142 = [
    "p14_2t", "p14_3t", "p14_5t", "p14_6t", "p14_7t",
    "p14_2n", "p14_3n", "p14_5n"
]
p142_all = sc.concat(sample_p142,keys=key_p142,label="sample")
#####################
sample_p24 = [
    p24_t2, p24_t4, p24_t5, p24_t6, p24_t7, 
    p24_n2
]
keys_p24 = [
    "p24_t2", "p24_t4", "p24_t5", "p24_t6", "p24_t7", 
    "p24_n2"
]
p24_all = sc.concat(sample_p24,keys=keys_p24,label="sample")
###################
sample_p31 = [
    p31_rcc81, p31_rcc84, p31_rcc86, p31_rcc87, p31_rcc94,
    p31_rcc96, p31_rcc99, p31_rcc100, p31_rcc101, p31_rcc103,
    p31_rcc104, p31_rcc106, p31_rcc112, p31_rcc113, p31_rcc114,
    p31_rcc115, p31_rcc116, p31_rcc119, p31_rcc120
]


key_p31_varnames = [
    "p31_rcc81", "p31_rcc84", "p31_rcc86", "p31_rcc87", "p31_rcc94",
    "p31_rcc96", "p31_rcc99", "p31_rcc100", "p31_rcc101", "p31_rcc103",
    "p31_rcc104", "p31_rcc106", "p31_rcc112", "p31_rcc113", "p31_rcc114",
    "p31_rcc115", "p31_rcc116", "p31_rcc119", "p31_rcc120"
]


p31_all = sc.concat(sample_p31, keys=key_p31_varnames, label="sample")

# %%
sample_all = [p22_all,p3_all,p11_all,p12_all,p141_all,p142_all,p24_all,p31_all]
series = ["GSE242299","GSE178481","GSE152938","GSE171306","GSE131685","GSE156632","GSE210038",'GSE207493']
adata = sc.concat(sample_all, keys = series,label="series",join="inner")
adata.obs['raw_barcode'] = adata.obs_names

# %%
adata.obs_names_make_unique()

# %%
adata.write_h5ad("adata_merge_raw_barcode.h5ad")

# %%
adata.write_h5ad("adata_merge.h5ad")

# %%
import warnings
import time

import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# Single-Cell Analysis Enhancement Tool

# GPU acceleration related
import cupy as cp
import rmm
from rmm.allocators.cupy import rmm_cupy_allocator

# Environment setup
warnings.filterwarnings('ignore')

# RMM and GPU memory allocation initialization
rmm.reinitialize(
    managed_memory=True,
    pool_allocator=False,
)
cp.cuda.set_allocator(rmm_cupy_allocator)

# Scanpy plotting parameters
sc.set_figure_params(figsize=(3, 3), dpi=150)

# %%
adata = sc.read_h5ad("adata_merge.h5ad")
sc.pp.filter_cells(adata, min_genes=200)
rsc.get.anndata_to_GPU(adata)
rsc.pp.scrublet(adata,batch_key='sample')
rsc.get.anndata_to_CPU(adata)
adata[~adata.obs['predicted_doublet']].write_h5ad('adata_merge_scrublet.h5ad')

# %%
adata=adata[~adata.obs['predicted_doublet']].copy()

# %%
def calculate_percent_mt(adata, pattern="MT-"):
    adata.var['MT'] = adata.var_names.str.startswith(pattern)
    sc.pp.calculate_qc_metrics(adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
    return adata

def calculate_percent_rps(adata, pattern="RPS"):
    adata.var['RIBO'] = adata.var_names.str.startswith(pattern)
    sc.pp.calculate_qc_metrics(adata, qc_vars=['RIBO'], percent_top=None, log1p=False, inplace=True)
    return adata

adata = calculate_percent_mt(adata)
adata = calculate_percent_rps(adata)
sc.pl.violin(
    adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_MT"],
    jitter=0,
    multi_panel=True,
)

# %%
sc.pp.filter_genes(adata, min_cells=3)  
sc.pp.filter_genes(adata, min_counts=10)

# %%
def subset_anndata(adata, n_genes_min=200, n_genes_max=5000, percent_mt_max=15):
    return adata[(adata.obs['n_genes'] > n_genes_min) & 
                 (adata.obs['n_genes'] < n_genes_max) & 
                 (adata.obs['pct_counts_MT'] < percent_mt_max), :]

adata = calculate_percent_mt(adata)
adata = calculate_percent_rps(adata)
adata = subset_anndata(adata)

# %%
adata

# %%
adata.write_h5ad("adata_qc.h5ad")

# %%
# Enhanced tools for single-cell analysis

# GPU acceleration libraries

# Ignore warnings
warnings.filterwarnings('ignore')

# RMM and GPU memory allocation initialization
rmm.reinitialize(
    managed_memory=True,
    pool_allocator=False,
)
cp.cuda.set_allocator(rmm_cupy_allocator)

# Global Scanpy plotting parameter settings
sc.set_figure_params(figsize=(3, 3), dpi=150)

# %%
adata = sc.read_h5ad("adata_qc.h5ad")
adata

# %%
rsc.get.anndata_to_GPU(adata)
rsc.pp.normalize_total(adata,target_sum=1e4)
rsc.pp.log1p(adata)
rsc.pp.highly_variable_genes(adata,n_top_genes=3000)
adata.raw = adata
adata = adata[:, adata.var["highly_variable"]].copy()
rsc.pp.regress_out(adata, keys=["total_counts", "pct_counts_MT"])
rsc.pp.scale(adata,max_value=10)
rsc.tl.pca(adata,n_comps=50)

# %%
rsc.pp.harmony_integrate(adata, key="sample",basis="X_pca",adjusted_basis="X_pca_inte")

# %%
rsc.pp.neighbors(adata, n_neighbors=30, n_pcs=15, use_rep='X_pca_inte')
rsc.tl.umap(adata)
rsc.tl.leiden(adata, resolution=0.5, key_added='leiden_res_0.5')

# %%
adata.write_h5ad('adata_inte_re.h5ad')

# %%
import decoupler as dc
sc.set_figure_params(figsize=(3.5,3.5),dpi=150)

# %%
adata = sc.read_h5ad("adata_inte_re.h5ad")
adata

# %%
sc.tl.rank_genes_groups(adata, groupby='leiden_res_0.5', method='t-test')

# %%
sc.pl.umap(adata,color='leiden_res_0.5')

# %%
result = adata.uns['rank_genes_groups']
all_top_genes = []
for group in result['names'].dtype.names: 
    group_data = pd.DataFrame({
        'gene': result['names'][group],
        'score': result['scores'][group],
        'logfoldchanges': result['logfoldchanges'][group],
        'pvals': result['pvals'][group],
        'pvals_adj': result['pvals_adj'][group]
    })

    top_50_genes = group_data.head(100)['gene'].tolist()
    all_top_genes.append({group: top_50_genes})
    group_data.to_csv(f'deg_{group}.csv', index=False)
    print(f"Based on single-cell literature on ccRCC and healthy kidney, determine what cell type this is.\nTop 100 DEGs in cluster {group}:")
    gene_list = result['names'][group][:100]
    print(", ".join(gene_list))

# %%
anno_dict={'0':'Mast Cells','1':'Epithelial Cells','2':'Myeloid Cells','3':'Myeloid Cells','4':'Epithelial Cells','5':'T Cells','6':'T Cells','7':'Endothelial Cells','8':'Stromal Cells',
          '9':'B Cells','10':'NK Cells','11':'Endothelial Cells'}
adata.obs['leiden_coarse'] = adata.obs['leiden_res_0.5'].map(anno_dict)

# %%
adata.obs

# %%
markers = {
    "B Cells": ["CD79B", "BANK1", "MS4A1"],
    "Endothelial Cells": ["VWF", "FLT1", "PECAM1"],
    "Epithelial Cells": ["KRT18", "KRT8", "EPCAM"],
    "Mast Cells": ["MS4A2", "TPSAB1", "KIT"],
    "Myeloid Cells": ["CD14", "LYZ", "CD68"],
    "NK Cells": ["NKG7", "GNLY", "KLRD1"],
    "Stromal Cells": ["RGS5", "TAGLN", "ACTA2"],
    "T Cells": ["CD3D", "CD3E", "CD3G"]
}

# %%
adata.write_h5ad('adata_anno_re.h5ad')

# %%
sc.tl.rank_genes_groups(adata, groupby='leiden_coarse', method='t-test')

# %%
result = adata.uns['rank_genes_groups']
all_top_genes = []
for group in result['names'].dtype.names: 
    group_data = pd.DataFrame({
        'gene': result['names'][group],
        'score': result['scores'][group],
        'logfoldchanges': result['logfoldchanges'][group],
        'pvals': result['pvals'][group],
        'pvals_adj': result['pvals_adj'][group]
    })

    top_50_genes = group_data.head(100)['gene'].tolist()
    all_top_genes.append({group: top_50_genes})
    group_data.to_csv(f'deg_{group}.csv', index=False)
    print(f"\nTop 50 DEGs in cluster {group}:")
    gene_list = result['names'][group][:50]
    print(", ".join(gene_list))

# %%
adata = sc.read('adata_anno_re.h5ad')

# %%
deg_epi = pd.read_csv('deg_Epithelial Cells.csv',index_col=0).head(100)
deg_b= pd.read_csv('deg_B Cells.csv',index_col=0).head(100)
deg_endo= pd.read_csv('deg_Endothelial Cells.csv',index_col=0).head(100)
deg_mast = pd.read_csv('deg_Mast Cells.csv',index_col=0).head(100)
deg_mye = pd.read_csv('deg_Myeloid Cells.csv',index_col=0).head(100)
deg_nk = pd.read_csv('deg_NK Cells.csv',index_col=0).head(100)
deg_s = pd.read_csv('deg_Stromal Cells.csv',index_col=0).head(100)
deg_t = pd.read_csv('deg_T Cells.csv',index_col=0).head(100)

# %%
deg_dict = {
    'Epi': deg_epi,
    'B_cell': deg_b,
    'Endo': deg_endo,
    'Mast': deg_mast,
    'Myeloid': deg_mye,
    'NK': deg_nk,
    'Stromal': deg_s,
    'T_cell': deg_t
}

for cell_type, df in deg_dict.items():
    gene_list = df.index.tolist()
    valid_genes = [g for g in gene_list if g in adata.raw.var_names]
    sc.tl.score_genes(adata, gene_list=valid_genes, score_name=f'{cell_type}_score',use_raw=True)

# %%
score_columns = [f'{cell_type}_score' for cell_type in deg_dict.keys()]
adata.obs['highest_score_type'] = adata.obs[score_columns].idxmax(axis=1)

# %%
score_columns = [f'{cell_type}_score' for cell_type in deg_dict.keys()]
for col in score_columns:
    adata.obs[f'{col}_rank'] = adata.obs[col].rank(method='min', ascending=False)
    adata.obs[f'{col}_rank_pct'] = adata.obs[col].rank(method='min', ascending=False, pct=True)
rank_pct_cols = [f'{col}_rank_pct' for col in score_columns]
print(adata.obs.groupby('leiden_coarse')[rank_pct_cols].mean().round(3))

# %%
pct_columns = rank_pct_cols
adata.obs['best_rank_type_global'] = adata.obs[pct_columns].idxmin(axis=1)

adata.obs['best_rank_type_global'] = adata.obs['best_rank_type_global'].str.replace('_score_rank_pct', '')

# %%
adata.write_h5ad('./adata_anno_score_genes_rank_re.h5ad')
